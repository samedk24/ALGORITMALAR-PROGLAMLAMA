# %%
x = 5

y = "Merhaba Dünya"

print(x)

print(y)
# Out:
# 5
# Merhaba Dünya

# %%
a = 10

print(type(a), a)
# Out:
# <class 'int'> 10

# %% [markdown]
# yukarıdakı kod yazdırıldığı zaman aşğadıdakilerden hangisinin çıktısı verilir

# %% [markdown]
# type hücrenin türünü verir

# %%
# int veri tipinden float'a çevirim işlemi örneği

y = 10

x = float(y)

print(x, type(x))
# Out:
# 10.0 <class 'float'>

# %%
# float veri tipinden int veri tipine çevirim örneği

y = 10.74

x = int(y)

print(x, type(x))
# Out:
# 10 <class 'int'>

# %%
# Boolean (True / Doğru - False / Yanlış) Değişken tanımlaması

d = True # 1 - Aktif
e = False # 0 - Pasif

print(d)
print(type(e))
# Out:
# True
# <class 'bool'>

# %%
# List - liste --> Dizi tanımlaması

liste = [1, 2, 3, 4, 5]

print(type(liste), liste)
# Out:
# <class 'list'> [1, 2, 3, 4, 5]

# %%
# List - liste --> Dizi tanımlaması

liste = [1, 2, 3, 4, 5]

print(type(liste), liste)
# Out:
# <class 'list'> [1, 2, 3, 4, 5]

# %%
# Dictionary - Sözlük Veri Tipi Tanımlaması --> Öğrenci Notlarını Tutan bir sözlük tanımlaması

notlar = {
    "bedo": 85,
    "izel": 90,
    "Anıl": 78
}

notlar["barış"] = 95 # yeni öğrenci ekleme yöntemi
notlar["bedo"] = 88 # mevucttaki öğrencinin notunu günleme işlemi

print(notlar)
# Out:
# {'bedo': 88, 'izel': 90, 'Anıl': 78, 'barış': 95}

# %%
print(notlar.keys())
print(notlar.values())
print(notlar.items())
# Out:
# dict_keys(['bedo', 'izel', 'Anıl', 'Fatma'])
# dict_values([88, 90, 78, 95])
# dict_items([('bedo', 88), ('izel', 90), ('Anıl', 78), ('Fatma', 95)])

# %%
# Set Küme veri tipi

kodyazanlar = {"Ahmet", "kaya", "anıl"}
kodyazmayanlar = {"bedo", "samed", "izel"}

ortak = kodyazanlar.intersection(kodyazmayanlar)
print("Kafasına Göre Takılan Arkadaşlar: ", ortak)

kod_yazmayanlar = kodyazmayanlar.difference(kodyazanlar)
print("Kod çalışması yapmayanlar: ", kod_yazmayanlar)

imzalistesi = kodyazanlar.union(kodyazmayanlar)
print("Sınıf İmza Listesi: ", imzalistesi)
# Out:
# Kafasına Göre Takılan Arkadaşlar:  set()
# Kod çalışması yapmayanlar:  {'samed', 'izel', 'bedo'}
# Sınıf İmza Listesi:  {'kaya', 'samed', 'anıl', 'bedo', 'Ahmet', 'izel'}

# %%
giris = input("5:")

print(giris)
# Out:
# 5:15
# 15

# %%
giris = input("Bir Sayı Giriniz:")
try:
    numara = float(giris)
    print("Girilen Sayı: ", numara)
except ValueError:
    print("Hatalı Bilgi Girişi Yaptınız Lütfen Tekrar Deneyiniz!")
# Out:
# Bir Sayı Giriniz:5
# Girilen Sayı:  5.0

# %%
import random

rastgele = random.random() # random fonksiyonu bize 0 ile 1 arasında rastgele bir sayı üreten fonksiyondur.

print("Rastgele Gelen Deger: ", rastgele)
# Out:
# Rastgele Gelen Deger:  0.35732526055231484

# %%
import random

rastgele2 = random.randint(1, 99) # randint fonksiyonu bize istediğimiz aralıkta rastgele bir sayı üreten fonksiyondur.

print("Rastgele Gelen Deger: ", rastgele2)
# Out:
# Rastgele Gelen Deger:  69

# %% [markdown]
# KODLAR VERİLİP DİĞER KISIMLARI BİZ YAPICAZ
